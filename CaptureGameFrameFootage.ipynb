# %%
# Based off of the original Python & OpenCV Footage Capture Tutorial by Nicholas Renotte
# Tutorial Link: https://www.youtube.com/watch?v=2VP9nOWiJ04

# %%
# Install Required Libraries & Packages
# PyAutoGui used to capture a screenshot of the current computer screen
# OpenCV-Python used for computer vision and image processing
# NumPy used to convert the output of PyAutoGui into an actual image or an array
# !pip install pyautogui opencv-python numpy
# Out:
# Requirement already satisfied: pyautogui in /home/maxbrette/.local/lib/python3.8/site-packages (0.9.53)
# Requirement already satisfied: opencv-python in /home/maxbrette/.local/lib/python3.8/site-packages (4.5.5.62)
# Requirement already satisfied: numpy in /home/maxbrette/.local/lib/python3.8/site-packages (1.18.5)
# Requirement already satisfied: pymsgbox in /home/maxbrette/.local/lib/python3.8/site-packages (from pyautogui) (1.0.9)
# Requirement already satisfied: PyTweening>=1.0.1 in /home/maxbrette/.local/lib/python3.8/site-packages (from pyautogui) (1.0.4)
# Requirement already satisfied: pygetwindow>=0.0.5 in /home/maxbrette/.local/lib/python3.8/site-packages (from pyautogui) (0.0.9)
# Requirement already satisfied: python3-Xlib; platform_system == "Linux" and python_version >= "3.0" in /home/maxbrette/.local/lib/python3.8/site-packages (from pyautogui) (0.15)
# Requirement already satisfied: mouseinfo in /home/maxbrette/.local/lib/python3.8/site-packages (from pyautogui) (0.1.3)
# Requirement already satisfied: pyscreeze>=0.1.21 in /home/maxbrette/.local/lib/python3.8/site-packages (from pyautogui) (0.1.28)
# Requirement already satisfied: pyrect in /home/maxbrette/.local/lib/python3.8/site-packages (from pygetwindow>=0.0.5->pyautogui) (0.1.4)
# Requirement already satisfied: pyperclip in /home/maxbrette/.local/lib/python3.8/site-packages (from mouseinfo->pyautogui) (1.8.2)
# Requirement already satisfied: Pillow>=6.2.1; python_version == "3.8" in /usr/lib/python3/dist-packages (from pyscreeze>=0.1.21->pyautogui) (7.0.0)

# %%
# On Linux, the Scrot application is required
# Documentation Link: https://pyautogui.readthedocs.io/en/latest/install.html

# Must be done in ther local command line terminal as it requires an input password
# sudo apt-get install scrot

# Should be automatically installed as Scrot' dependenciess if the previou code line is run
# sudo apt-get install python3-tk
# sudo apt-get install python3-dev

# %%
# Verify that the desired libraries & packages have been successfully installed
# !pip list
# Out:
# Package                    Version
# -------------------------- ---------------------
# absl-py                    1.0.0
# aiohttp                    3.8.1
# aiosignal                  1.2.0
# ale-py                     0.7.3
# alembic                    1.7.6
# analytics-python           1.4.0
# ansible                    2.9.6
# anyio                      3.5.0
# apache-libcloud            2.8.0
# apturl                     0.5.2
# argcomplete                1.8.1
# argon2-cffi                21.3.0
# argon2-cffi-bindings       21.2.0
# asgiref                    3.5.0
# asttokens                  2.0.5
# astunparse                 1.6.3
# async-timeout              4.0.2
# atari-py                   0.2.6
# attrs                      19.3.0
# Automat                    0.8.0
# autopage                   0.5.0
# AutoROM                    0.4.2
# AutoROM.accept-rom-license 0.4.2
# backcall                   0.2.0
# backoff                    1.10.0
# bcrypt                     3.1.7
# black                      22.1.0
# bleach                     4.1.0
# blinker                    1.4
# blis                       0.7.5
# Boruta                     0.3
# Brlapi                     0.7.0
# cachetools                 5.0.0
# catalogue                  1.0.0
# certifi                    2019.11.28
# cffi                       1.15.0
# chardet                    3.0.4
# charset-normalizer         2.0.11
# click                      8.0.3
# cliff                      3.10.1
# cloudpickle                1.6.0
# cmaes                      0.8.2
# cmd2                       2.4.0
# colorama                   0.4.3
# colorlog                   6.6.0
# colorlover                 0.3.0
# command-not-found          0.3
# constantly                 15.1.0
# cryptography               2.8
# cufflinks                  0.17.3
# cupshelpers                1.0
# cycler                     0.11.0
# cymem                      2.0.6
# databricks-cli             0.16.4
# dbus-python                1.2.16
# debugpy                    1.5.1
# decorator                  5.1.1
# defer                      1.0.6
# defusedxml                 0.7.1
# distro                     1.4.0
# distro-info                0.23ubuntu1
# dnspython                  1.16.0
# docker                     5.0.3
# duplicity                  0.8.12.0
# entrypoints                0.3
# epoptes                    22.01-1-ubuntu20.04.1
# executing                  0.8.2
# fastapi                    0.73.0
# fasteners                  0.14.1
# ffmpy                      0.3.0
# filelock                   3.4.2
# Flask                      2.0.2
# fonttools                  4.29.1
# frozenlist                 1.3.0
# funcy                      1.17
# future                     0.18.2
# gast                       0.3.3
# gensim                     3.8.3
# gitdb                      4.0.9
# GitPython                  3.1.26
# google-auth                2.6.0
# google-auth-oauthlib       0.4.6
# google-pasta               0.2.0
# gradio                     2.7.5.2
# greenlet                   1.1.2
# grpcio                     1.43.0
# gunicorn                   20.1.0
# gym                        0.19.0
# gym-retro                  0.8.0
# gym-super-mario-bros       7.3.0
# h11                        0.13.0
# h5py                       2.10.0
# htmlmin                    0.1.12
# httplib2                   0.14.0
# huggingface-hub            0.4.0
# hyperlink                  19.0.0
# ibm-cloud-sdk-core         3.14.0
# ibm-watson                 5.3.1
# idna                       2.8
# ImageHash                  4.2.1
# imbalanced-learn           0.7.0
# importlib-metadata         4.10.1
# importlib-resources        5.4.0
# incremental                16.10.1
# ipykernel                  6.7.0
# ipython                    8.0.1
# ipython-genutils           0.2.0
# ipywidgets                 7.6.5
# itsdangerous               2.0.1
# jedi                       0.18.1
# Jinja2                     3.0.3
# jmespath                   0.9.4
# joblib                     1.1.0
# jsonschema                 4.4.0
# jupyter-client             7.1.2
# jupyter-core               4.9.1
# jupyterlab-pygments        0.1.2
# jupyterlab-widgets         1.0.2
# Keras-Preprocessing        1.1.2
# keras-rl2                  1.0.5
# keyring                    18.0.1
# kiwisolver                 1.3.2
# kmodes                     0.11.1
# language-selector          0.1
# launchpadlib               1.10.13
# lazr.restfulclient         0.14.2
# lazr.uri                   1.0.3
# lightgbm                   3.3.2
# llvmlite                   0.38.0
# lockfile                   0.12.2
# louis                      3.12.0
# macaroonbakery             1.3.1
# Mako                       1.1.0
# Markdown                   3.3.6
# markdown2                  2.4.2
# MarkupSafe                 2.0.1
# matplotlib                 3.5.1
# matplotlib-inline          0.1.3
# missingno                  0.5.0
# mistune                    0.8.4
# mlflow                     1.23.1
# mlxtend                    0.19.0
# monotonic                  1.5
# MouseInfo                  0.1.3
# multidict                  6.0.2
# multimethod                1.7
# murmurhash                 1.0.6
# mypy-extensions            0.4.3
# nbclient                   0.5.10
# nbconvert                  6.4.1
# nbformat                   5.1.3
# nes-py                     8.1.8
# nest-asyncio               1.5.4
# netaddr                    0.7.19
# netifaces                  0.10.4
# networkx                   2.6.3
# nltk                       3.7
# notebook                   6.4.8
# ntlm-auth                  1.1.0
# numba                      0.55.1
# numexpr                    2.8.1
# numpy                      1.18.5
# oauthlib                   3.1.0
# olefile                    0.46
# opencv-python              4.5.5.62
# opt-einsum                 3.3.0
# optuna                     2.10.0
# packaging                  21.3
# panda                      0.3.1
# pandas                     1.4.0
# pandas-profiling           3.1.0
# pandocfilters              1.5.0
# paramiko                   2.6.0
# parso                      0.8.3
# pathspec                   0.9.0
# patsy                      0.5.2
# pbr                        5.8.1
# pexpect                    4.6.0
# phik                       0.12.0
# pickleshare                0.7.5
# Pillow                     7.0.0
# pip                        20.0.2
# plac                       1.1.3
# platformdirs               2.4.1
# plotly                     5.6.0
# preshed                    3.0.6
# prettytable                3.1.1
# prometheus-client          0.13.1
# prometheus-flask-exporter  0.18.7
# prompt-toolkit             3.0.26
# protobuf                   3.19.4
# psutil                     5.9.0
# ptyprocess                 0.7.0
# pure-eval                  0.2.2
# pyasn1                     0.4.2
# pyasn1-modules             0.2.1
# PyAutoGUI                  0.9.53
# pycairo                    1.16.2
# pycaret                    2.3.6
# pycparser                  2.21
# pycrypto                   2.6.1
# pycryptodome               3.14.1
# pycups                     1.9.73
# pydantic                   1.9.0
# pydub                      0.25.1
# PyGetWindow                0.0.9
# pyglet                     1.5.11
# Pygments                   2.11.2
# PyGObject                  3.36.0
# PyHamcrest                 1.9.0
# PyJWT                      2.3.0
# pykerberos                 1.1.14
# pyLDAvis                   3.3.1
# pymacaroons                0.13.0
# PyMsgBox                   1.0.9
# PyNaCl                     1.3.0
# pynndescent                0.5.6
# pyod                       0.9.7
# pyOpenSSL                  19.0.0
# pyparsing                  3.0.7
# pyperclip                  1.8.2
# PyRect                     0.1.4
# pyRFC3339                  1.1
# pyrsistent                 0.18.1
# PyScreeze                  0.1.28
# python-apt                 2.0.0+ubuntu0.20.4.6
# python-dateutil            2.8.2
# python-debian              0.1.36ubuntu1
# python-multipart           0.0.5
# python3-xlib               0.15
# pytweening                 1.0.4
# pytz                       2021.3
# PyWavelets                 1.2.0
# pywinrm                    0.3.0
# pyxdg                      0.26
# PyYAML                     5.3.1
# pyzmq                      22.3.0
# querystring-parser         1.2.4
# regex                      2022.1.18
# reportlab                  3.5.34
# requests                   2.27.1
# requests-kerberos          0.12.0
# requests-ntlm              1.1.0
# requests-oauthlib          1.3.1
# requests-unixsocket        0.2.0
# rsa                        4.8
# sacremoses                 0.0.47
# scikit-learn               0.23.2
# scikit-plot                0.3.7
# scipy                      1.5.4
# seaborn                    0.11.2
# SecretStorage              2.3.1
# selinux                    3.0
# Send2Trash                 1.8.0
# service-identity           18.1.0
# setuptools                 45.2.0
# shap                       0.40.0
# simplejson                 3.16.0
# six                        1.14.0
# sklearn                    0.0
# slicer                     0.0.7
# smart-open                 5.2.1
# smmap                      5.0.0
# sniffio                    1.2.0
# spacy                      2.3.7
# SQLAlchemy                 1.4.31
# sqlparse                   0.4.2
# srsly                      1.0.5
# ssh-import-id              5.10
# stable-baselines3          1.4.0
# stack-data                 0.1.4
# starlette                  0.17.1
# statsmodels                0.13.2
# stevedore                  3.5.0
# systemd-python             234
# tabulate                   0.8.9
# tangled-up-in-unicode      0.1.0
# tenacity                   8.0.1
# tensorboard                2.8.0
# tensorboard-data-server    0.6.1
# tensorboard-plugin-wit     1.8.1
# tensorflow                 2.3.1
# tensorflow-estimator       2.3.0
# termcolor                  1.1.0
# terminado                  0.13.1
# testpath                   0.5.0
# textblob                   0.17.1
# thinc                      7.4.5
# threadpoolctl              3.1.0
# tokenizers                 0.11.4
# tomli                      2.0.0
# torch                      1.8.2+cu111
# torchaudio                 0.8.2
# torchvision                0.9.2+cu111
# tornado                    6.1
# tqdm                       4.62.3
# traitlets                  5.1.1
# transformers               4.16.2
# Twisted                    18.9.0
# typing-extensions          4.0.1
# ubuntu-advantage-tools     27.5
# ubuntu-drivers-common      0.0.0
# ufw                        0.36
# umap-learn                 0.5.2
# unattended-upgrades        0.1
# urllib3                    1.26.8
# usb-creator                0.3.7
# uvicorn                    0.17.4
# visions                    0.7.4
# vizdoom                    1.1.11
# wadllib                    1.3.3
# wasabi                     0.9.0
# wcwidth                    0.2.5
# webencodings               0.5.1
# websocket-client           1.1.0
# Werkzeug                   2.0.3
# wheel                      0.34.2
# widgetsnbextension         3.5.2
# wordcloud                  1.8.1
# wrapt                      1.13.3
# xkit                       0.0.0
# xmltodict                  0.12.0
# yarl                       1.7.2
# yellowbrick                1.3.post1
# zipp                       3.7.0
# zope.interface             4.7.1

# %%
# Import The Dependencies
import pyautogui
import cv2
import numpy as np

# %%
# Loops over the individual game frames
while True:
    
    # Takes a complete screen capture of the current computer screen
    screen = pyautogui.screenshot()
    
    # Converts the outputted screen capture into a numpy array
    screenArray = np.array(screen)
    
    # Crops out the desired region of the screen capture via index slicing (Adjust as needed)
    # First value is height (By pixel = Start:Finish)
    # Second value is width
    # Third value is the Red, Green, Blue color value channels
    croppedRegion = screenArray[ :600, 1120: , : ]
    
    # Convert the color channel order
    # Open CV2 expect the color format to come is a Blue, Green, Red as opposed to the standard Red, Green, Blue
    # giving the captured image a strange tint that must be rectified, adjust the color channel order
    correctedColors = cv2.cvtColor(croppedRegion, cv2.COLOR_RGB2BGR)
    
    # Handles the rendering of the images and videos
    cv2.imshow('CaptureGameFrameFootage', correctedColors)
    
    # CV2.WaitKey in order to give the in game frame a chance to reupdate
    # Gives a delay in miliseconds then checks if the 'q' letter has been hit on the keyboard
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
    
    # Closes down the current OpenCV2 frame
    cv2.destroyAllWindows
